# %% [markdown]
# <a href="https://colab.research.google.com/github/heloisapbarros/BTE320/blob/main/In_class_assignment_Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
op = input("Enter an operator (+, -, *, /): ")
if op == "+":
  print("Result:", num1 + num2)
elif op == "*":
  print("Result:", num1 * num2)
elif op == "/":
  if num2 == 0:
    print("Error: cannot divide by zero.")
  else:
    print("Result:", num1 / num2)
else:
  print("Invalid operator.")
# Out:
# Enter the first number: 3
# Enter the second number: 3
# Enter an operator (+, -, *, /): +
# Result: 6.0
