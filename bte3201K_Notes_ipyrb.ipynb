# %% [markdown]
# <a href="https://colab.research.google.com/github/heloisapbarros/BTE320/blob/main/bte3201K_Notes_ipyrb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
#   File "/tmp/ipython-input-1346780967.py", line 1
#     1 print('Hello')
#       ^
# SyntaxError: invalid syntax

# %%
1 x = 2
# Out:
#   File "/tmp/ipython-input-892805676.py", line 1
#     1 x = 2
#       ^
# SyntaxError: invalid syntax
