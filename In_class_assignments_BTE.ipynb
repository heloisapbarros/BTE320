# %% [markdown]
# <a href="https://colab.research.google.com/github/heloisapbarros/BTE320/blob/main/In_class_assignments_BTE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter the sales: ($) "))
# Out:
# Enter the sales: ($) 12000

# %%
cogs = 0.40 * sales
grossprofit = sales - cogs
print("The gross profit is: $", grossprofit)
print("The cost of goods sold (COGS) is: $", cogs)
# Out:
# The gross profit is: $ 7200.0
# The cost of goods sold (COGS) is: $ 4800.0

# %% [markdown]
# taxrate = float(input("Enter tax rate (%): "))

# %%
taxrate = float(input("Enter tax rate (%): "))
taxes = grossprofit * (taxrate/100)
netincome = grossprofit - taxes
print("The taxes are: $", taxes)
print("The net income is: $", netincome)
# Out:
# Enter tax rate (%): 30
# The taxes are: $ 2160.0
# The net income is: $ 5040.0
