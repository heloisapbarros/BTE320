# %% [markdown]
# <a href="https://colab.research.google.com/github/heloisapbarros/BTE320/blob/main/In_class_assignment_2_week_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ticket_price = 10
base_attendance = 20
fixed_cost = 200


for ad in range(0, 201, 25):
    revenue = (base_attendance + 2 * round(ad ** 0.5))*10
    costs = fixed_cost + ad
    profit = revenue - costs
    print(ad, profit)
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80
