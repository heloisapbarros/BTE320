# %% [markdown]
# <a href="https://colab.research.google.com/github/heloisapbarros/BTE320/blob/main/In_class_assignment_week_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base_fee = 5
hourly_rate = 2.5

for hours in range(1, 9):
    fee = base_fee + hourly_rate * hours
    print(hours, fee)
# Out:
# 1 7.5
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 22.5
# 8 25.0

# %%
base_fee = 5
hourly_rate = 2.5

for hours in range(1, 9):
    fee = base_fee + hourly_rate * hours

    if fee < 10:
        fee = 10
    elif fee > 20:
        fee = 20

    print(hours, fee)
# Out:
# 1 10
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20
# 8 20
